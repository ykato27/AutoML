# %% [markdown]
# <a href="https://colab.research.google.com/github/ykato27/AutoML-AutoGluon/blob/main/AutoGluon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pip
# !pip install --upgrade setuptools
# !pip install --upgrade "mxnet<2.0.0"
# !pip install --pre autogluon
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (21.1.2)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (57.0.0)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: mxnet<2.0.0 in /usr/local/lib/python3.7/dist-packages (1.8.0.post0)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet<2.0.0) (2.23.0)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.7/dist-packages (from mxnet<2.0.0) (1.19.5)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from mxnet<2.0.0) (0.8.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2.10)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: autogluon in /usr/local/lib/python3.7/dist-packages (0.2.1b20210614)
# Requirement already satisfied: autogluon.mxnet==0.2.1b20210614 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.2.1b20210614)
# Requirement already satisfied: autogluon.text==0.2.1b20210614 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.2.1b20210614)
# Requirement already satisfied: autogluon.extra==0.2.1b20210614 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.2.1b20210614)
# Requirement already satisfied: autogluon.vision==0.2.1b20210614 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.2.1b20210614)
# Requirement already satisfied: autogluon.tabular[all]==0.2.1b20210614 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.2.1b20210614)
# Requirement already satisfied: autogluon.core==0.2.1b20210614 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.2.1b20210614)
# Requirement already satisfied: autogluon.features==0.2.1b20210614 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.2.1b20210614)
# Requirement already satisfied: numpy==1.19.5 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (1.19.5)
# Requirement already satisfied: autograd>=1.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (3.2.2)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (1.1.5)
# Requirement already satisfied: ConfigSpace==0.4.18 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (0.4.18)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (1.17.94)
# Requirement already satisfied: dill==0.3.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (0.3.3)
# Requirement already satisfied: paramiko>=2.4 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (2.7.2)
# Requirement already satisfied: scipy<1.7,>=1.5.4 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (1.6.3)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (4.41.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (0.29.23)
# Requirement already satisfied: tornado>=5.0.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (5.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (2.23.0)
# Requirement already satisfied: distributed>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (2021.6.0)
# Requirement already satisfied: scikit-learn<0.25,>=0.23.2 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (0.24.2)
# Requirement already satisfied: dask>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (2021.6.0)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210614->autogluon) (0.8.4)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.2.1b20210614->autogluon) (3.6.4)
# Requirement already satisfied: openml in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.2.1b20210614->autogluon) (0.12.2)
# Requirement already satisfied: gluoncv<0.10.4,>=0.10.2.post0 in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.2.1b20210614->autogluon) (0.10.2.post0)
# Requirement already satisfied: Pillow<=8.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.mxnet==0.2.1b20210614->autogluon) (7.1.2)
# Requirement already satisfied: psutil<5.9,>=5.7.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.2.1b20210614->autogluon) (5.8.0)
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.2.1b20210614->autogluon) (2.5.1)
# Requirement already satisfied: lightgbm<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.2.1b20210614->autogluon) (3.2.1)
# Requirement already satisfied: fastai<3.0,>=2.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.2.1b20210614->autogluon) (2.3.1)
# Requirement already satisfied: xgboost<1.4,>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.2.1b20210614->autogluon) (1.3.3)
# Requirement already satisfied: torch<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.2.1b20210614->autogluon) (1.8.1+cu101)
# Requirement already satisfied: catboost<0.26,>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.2.1b20210614->autogluon) (0.25.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from autogluon.text==0.2.1b20210614->autogluon) (3.0.0)
# Requirement already satisfied: autogluon-contrib-nlp==0.0.1b20210201 in /usr/local/lib/python3.7/dist-packages (from autogluon.text==0.2.1b20210614->autogluon) (0.0.1b20210201)
# Requirement already satisfied: tokenizers==0.9.4 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (0.9.4)
# Requirement already satisfied: contextvars in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (2.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (3.12.4)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (1.5.1)
# Requirement already satisfied: sentencepiece==0.1.95 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (0.1.95)
# Requirement already satisfied: sacremoses>=0.0.38 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (0.0.45)
# Requirement already satisfied: yacs>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (0.1.8)
# Requirement already satisfied: flake8 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (3.9.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (2019.12.20)
# Requirement already satisfied: d8<1.0,>=0.0.2 in /usr/local/lib/python3.7/dist-packages (from autogluon.vision==0.2.1b20210614->autogluon) (0.0.2.post0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace==0.4.18->autogluon.core==0.2.1b20210614->autogluon) (2.4.7)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.3->autogluon.core==0.2.1b20210614->autogluon) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.2.1b20210614->autogluon) (1.15.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.2.1b20210614->autogluon) (4.4.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.2.1b20210614->autogluon) (2.0.2)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.2.1b20210614->autogluon) (1.5.12)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (1.6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (0.11.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (2021.6.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (1.2.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (3.13)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (2.0.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (7.1.2)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (1.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (57.0.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (2.4.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (1.0.2)
# Requirement already satisfied: fastcore<1.4,>=1.3.8 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (1.3.20)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (0.9.1+cu101)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (20.9)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (21.1.2)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (2.2.4)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (1.0.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.4,>=0.10.2.post0->autogluon.extra==0.2.1b20210614->autogluon) (2.0.0)
# Requirement already satisfied: autocfg in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.4,>=0.10.2.post0->autogluon.extra==0.2.1b20210614->autogluon) (0.0.8)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.4,>=0.10.2.post0->autogluon.extra==0.2.1b20210614->autogluon) (4.1.2.30)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.2.1b20210614->autogluon) (0.36.2)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx<3.0,>=2.3->autogluon.tabular[all]==0.2.1b20210614->autogluon) (4.4.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.2.1b20210614->autogluon) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.2.1b20210614->autogluon) (2018.9)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->autogluon.core==0.2.1b20210614->autogluon) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->autogluon.core==0.2.1b20210614->autogluon) (1.4.0)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->autogluon.core==0.2.1b20210614->autogluon) (3.4.7)
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.2.1b20210614->autogluon) (1.14.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.2.1b20210614->autogluon) (2.20)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (0.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.38->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.2.1b20210614->autogluon) (2.1.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (3.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (2.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (0.8.2)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (4.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.2.1b20210614->autogluon) (3.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.2.1b20210614->autogluon) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.2.1b20210614->autogluon) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.2.1b20210614->autogluon) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.2.1b20210614->autogluon) (3.0.4)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.2.1b20210614->autogluon) (1.0.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->autogluon.core==0.2.1b20210614->autogluon) (0.10.0)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from boto3->autogluon.core==0.2.1b20210614->autogluon) (0.4.2)
# Requirement already satisfied: botocore<1.21.0,>=1.20.94 in /usr/local/lib/python3.7/dist-packages (from boto3->autogluon.core==0.2.1b20210614->autogluon) (1.20.94)
# Requirement already satisfied: immutables>=0.9 in /usr/local/lib/python3.7/dist-packages (from contextvars->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (0.15)
# Requirement already satisfied: pycodestyle<2.8.0,>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (2.7.0)
# Requirement already satisfied: pyflakes<2.4.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (2.3.1)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210614->autogluon) (0.6.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.2.1b20210614->autogluon) (5.0.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.2.1b20210614->autogluon) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.2.1b20210614->autogluon) (1.3.1)
# Requirement already satisfied: liac-arff>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from openml->autogluon.extra==0.2.1b20210614->autogluon) (2.5.0)
# Requirement already satisfied: minio in /usr/local/lib/python3.7/dist-packages (from openml->autogluon.extra==0.2.1b20210614->autogluon) (7.0.4)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.7/dist-packages (from openml->autogluon.extra==0.2.1b20210614->autogluon) (0.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.2.1b20210614->autogluon) (1.3.3)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.2.1b20210614->autogluon) (8.8.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.2.1b20210614->autogluon) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.2.1b20210614->autogluon) (1.4.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.2.1b20210614->autogluon) (1.10.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.2.1b20210614->autogluon) (21.2.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.2.1b20210614->autogluon) (1.3)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
# ライブラリーのインポート
import autogluon as ag
from autogluon.tabular import TabularDataset, TabularPredictor

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ボストンの住宅価格データ
from sklearn.datasets import load_boston

# 評価指標
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
# データセットの読込み
boston = load_boston()

# 説明変数の格納
df = pd.DataFrame(boston.data, columns=boston.feature_names)
# 目的変数の追加
df["MEDV"] = boston.target

# データの中身を確認
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
# ランダムシード値
RANDOM_STATE = 10

# 学習データと評価データの割合
TEST_SIZE = 0.2

# 学習データと評価データを作成
x_train, x_test, y_train, y_test = train_test_split(
    df.iloc[:, 0 : df.shape[1] - 1],
    df.iloc[:, df.shape[1] - 1],
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
)

# trainのデータセットの2割をモデル学習時のバリデーションデータとして利用する
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=TEST_SIZE, random_state=RANDOM_STATE
)

df_train = pd.concat([x_train, y_train], axis=1)
df_valid = pd.concat([x_valid, y_valid], axis=1)

# %%
predictor = TabularPredictor(
    label='MEDV',
    problem_type='regression', 
    eval_metric='root_mean_squared_error',
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210615_035127/"

# %%
predictor.fit(
            train_data=df_train,
            tuning_data=df_valid,
            time_limit=None,
)
# Out:
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210615_035127/"
# AutoGluon Version:  0.2.1b20210614
# Train Data Rows:    323
# Train Data Columns: 13
# Tuning Data Rows:    81
# Tuning Data Columns: 13
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12731.1 MB
# 	Train Data (Original)  Memory Usage: 0.04 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', ...]
# 	0.1s = Fit runtime
# 	13 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# NumExpr defaulting to 2 threads.
# 	-5.1686	 = Validation root_mean_squared_error score
# 	0.02s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-4.9082	 = Validation root_mean_squared_error score
# 	0.01s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBMXT ...
# /usr/local/lib/python3.7/dist-packages/fsspec/__init__.py:49: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for spec in entry_points.get("fsspec.specs", []):
# 	-3.4043	 = Validation root_mean_squared_error score
# 	0.44s	 = Training runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# [1000]	train_set's rmse: 0.367521	valid_set's rmse: 2.89849
# 	-2.8857	 = Validation root_mean_squared_error score
# 	0.75s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-3.0262	 = Validation root_mean_squared_error score
# 	0.85s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-2.5772	 = Validation root_mean_squared_error score
# 	3.32s	 = Training runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-2.8088	 = Validation root_mean_squared_error score
# 	0.63s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-3.1452	 = Validation root_mean_squared_error score
# 	1.18s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-2.765	 = Validation root_mean_squared_error score
# 	0.54s	 = Training runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	-2.8305	 = Validation root_mean_squared_error score
# 	4.92s	 = Training runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-2.634	 = Validation root_mean_squared_error score
# 	0.94s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-2.4395	 = Validation root_mean_squared_error score
# 	0.45s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 16.05s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20210615_035127/")

# %%
y_pred = predictor.predict(x_test)

# %%
# 評価
def calculate_scores(true, pred):
    """全ての評価指標を計算する

    Parameters
    ----------
    true (np.array)       : 実測値
    pred (np.array)       : 予測値

    Returns
    -------
    scores (pd.DataFrame) : 各評価指標を纏めた結果

    """
    scores = {}
    scores = pd.DataFrame(
        {
            "R2": r2_score(true, pred),
            "MAE": mean_absolute_error(true, pred),
            "MSE": mean_squared_error(true, pred),
            "RMSE": np.sqrt(mean_squared_error(true, pred)),
        },
        index=["scores"],
    )
    return scores

# %%
scores = calculate_scores(y_test, y_pred)
print(scores)
# Out:
#               R2      MAE        MSE     RMSE
# scores  0.884956  2.43223  12.031392  3.46863

# %%
predictor.leaderboard(df_valid, silent=True)
# Out:
#                   model  score_test  ...  can_infer  fit_order
# 0   WeightedEnsemble_L2   -2.439540  ...       True         12
# 1              CatBoost   -2.577247  ...       True          6
# 2         LightGBMLarge   -2.634021  ...       True         11
# 3               XGBoost   -2.765037  ...       True          9
# 4         ExtraTreesMSE   -2.808843  ...       True          7
# 5        NeuralNetMXNet   -2.830514  ...       True         10
# 6              LightGBM   -2.885714  ...       True          4
# 7       RandomForestMSE   -3.026227  ...       True          5
# 8       NeuralNetFastAI   -3.145224  ...       True          8
# 9            LightGBMXT   -3.404250  ...       True          3
# 10       KNeighborsDist   -4.908206  ...       True          2
# 11       KNeighborsUnif   -5.168594  ...       True          1
#
# [12 rows x 12 columns]

# %%
results = predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   WeightedEnsemble_L2  -2.439540       0.258650  10.936155                0.000638           0.452443            2       True         12
# 1              CatBoost  -2.577247       0.002005   3.321350                0.002005           3.321350            1       True          6
# 2         LightGBMLarge  -2.634021       0.007841   0.938447                0.007841           0.938447            1       True         11
# 3               XGBoost  -2.765037       0.004887   0.543379                0.004887           0.543379            1       True          9
# 4         ExtraTreesMSE  -2.808843       0.103029   0.629762                0.103029           0.629762            1       True          7
# 5        NeuralNetMXNet  -2.830514       0.126151   4.916997                0.126151           4.916997            1       True         10
# 6              LightGBM  -2.885714       0.014084   0.753322                0.014084           0.753322            1       True          4
# 7       RandomForestMSE  -3.026227       0.102855   0.854194                0.102855           0.854194            1       True          5
# 8       NeuralNetFastAI  -3.145224       0.015513   1.177875                0.015513           1.177875            1       True          8
# 9            LightGBMXT  -3.404250       0.003379   0.444052                0.003379           0.444052            1       True          3
# 10       KNeighborsDist  -4.908206       0.103044   0.010219                0.103044           0.010219            1       True          2
# 11       KNeighborsUnif  -5.168594       0.103844   0.023347                0.103844           0.023347            1       True          1
# Number of models trained: 12
# Types of models trained:
# {'RFModel', 'CatBoostModel', 'KNNModel', 'XGBoostModel', 'NNFastAiTabularModel', 'LGBModel', 'XTModel', 'WeightedEnsembleModel', 'TabularNeuralNetModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 13 | ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', ...]
# Plot summary of models saved to file: AutogluonModels/ag-20210615_035127/SummaryOfModels.html
# *** End of fit() summary ***
