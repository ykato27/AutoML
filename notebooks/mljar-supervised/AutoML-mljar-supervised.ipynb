# %% [markdown]
# ## AutoML-mljar-supervised サンプルコード

# %%
# %load_ext lab_black

# %%
# ライブラリーのインポート
import os

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# ボストンの住宅価格データ
from sklearn.datasets import load_boston

# 前処理
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# MLJAR AutoML
import supervised
from supervised.automl import AutoML

# 評価指標
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
print(supervised.__version__)
# Out:
# 0.10.6

# %%
# データセットの読込み
boston = load_boston()

# 説明変数の格納
df = pd.DataFrame(boston.data, columns=boston.feature_names)
# 目的変数の追加
df["MEDV"] = boston.target

# データの中身を確認
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# ランダムシード値
RANDOM_STATE = 10

# 学習データと評価データの割合
TEST_SIZE = 0.2

# 学習データと評価データを作成
x_train, x_test, y_train, y_test = train_test_split(
    df.iloc[:, 0 : df.shape[1] - 1],
    df.iloc[:, df.shape[1] - 1],
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
)

# %%
# %%time

# Explain mode
automl_explain = AutoML(mode="Explain", total_time_limit=120, random_state=RANDOM_STATE)
automl_explain.fit(x_train, y_train)
# Out:
# AutoML directory: AutoML_1
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['Baseline', 'Linear', 'Decision Tree', 'Random Forest', 'Xgboost', 'Neural Network']
# AutoML will ensemble availabe models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'ensemble']
# * Step simple_algorithms will try to check up to 3 models
# 1_Baseline rmse 9.863249 trained in 0.73 seconds
# 2_DecisionTree rmse 5.632212 trained in 24.52 seconds
# 3_Linear rmse 5.562562 trained in 6.96 seconds
# * Step default_algorithms will try to check up to 3 models
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# 4_Default_Xgboost rmse 4.158365 trained in 13.56 seconds
# 5_Default_NeuralNetwork rmse 5.806764 trained in 1.94 seconds
# 6_Default_RandomForest rmse 4.88984 trained in 11.35 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble rmse 4.158365 trained in 0.9 seconds
# An input array is constant; the correlation coefficient is not defined.
# AutoML fit time: 96.1 seconds
# AutoML best model: 4_Default_Xgboost
# CPU times: user 1min 20s, sys: 14.4 s, total: 1min 34s
# Wall time: 1min 36s
# AutoML(random_state=10, total_time_limit=120)

# %%
# %%time

# Perform mode
automl_perform = AutoML(mode="Perform", total_time_limit=120, random_state=RANDOM_STATE)
automl_perform.fit(x_train, y_train)
# Out:
# AutoML directory: AutoML_2
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['Linear', 'Random Forest', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network']
# AutoML will ensemble availabe models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'ensemble']
# * Step simple_algorithms will try to check up to 1 model
# 1_Linear rmse 4.613829 trained in 7.24 seconds (1-sample predict time 0.1703 seconds)
# * Step default_algorithms will try to check up to 5 models
# 2_Default_LightGBM rmse 3.262666 trained in 43.23 seconds (1-sample predict time 0.0927 seconds)
# * Step not_so_random will try to check up to 20 models
# 7_LightGBM rmse 3.399441 trained in 31.67 seconds (1-sample predict time 0.101 seconds)
# Skip golden_features because of the time limit.
# Skip insert_random_feature because of the time limit.
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 4 models
# 8_LightGBM rmse 3.262666 trained in 44.63 seconds (1-sample predict time 0.1073 seconds)
# Skip hill_climbing_2 because of the time limit.
# * Step ensemble will try to check up to 1 model
# Ensemble rmse 3.200319 trained in 0.63 seconds (1-sample predict time 0.2844 seconds)
# AutoML fit time: 148.68 seconds
# AutoML best model: Ensemble
# CPU times: user 1min 20s, sys: 39.4 s, total: 2min
# Wall time: 2min 28s
# AutoML(mode='Perform', random_state=10, total_time_limit=120)

# %%
# %%time

# Compete mode
automl_compete = AutoML(mode="Compete", total_time_limit=120, random_state=RANDOM_STATE)
automl_compete.fit(x_train, y_train)
# Out:
# AutoML directory: AutoML_3
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['Decision Tree', 'Linear', 'Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network', 'Nearest Neighbors']
# AutoML will stack models
# AutoML will ensemble availabe models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree rmse 4.162736 trained in 1.05 seconds
# Disable stacking for split validation
# * Step simple_algorithms will try to check up to 3 models
# 2_DecisionTree rmse 6.857707 trained in 1.03 seconds
# 3_DecisionTree rmse 4.681484 trained in 0.99 seconds
# 4_Linear rmse 6.106102 trained in 1.38 seconds
# * Step default_algorithms will try to check up to 7 models
# 5_Default_LightGBM rmse 3.828625 trained in 16.75 seconds
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# 6_Default_Xgboost rmse 3.537102 trained in 3.13 seconds
# * Step not_so_random will try to check up to 63 models
# 16_LightGBM rmse 3.986159 trained in 11.25 seconds
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# 7_Xgboost rmse 4.215637 trained in 1.8 seconds
# 25_CatBoost rmse 5.013433 trained in 2.93 seconds
# 34_RandomForest rmse 4.78728 trained in 3.11 seconds
# 43_ExtraTrees rmse 4.116552 trained in 2.11 seconds
# 52_NeuralNetwork rmse 7.168914 trained in 1.16 seconds
# 61_NearestNeighbors rmse 5.402386 trained in 1.14 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: B_ratio_LSTAT
# Add Golden Feature: LSTAT_sum_PTRATIO
# Add Golden Feature: LSTAT_ratio_B
# Add Golden Feature: LSTAT_sum_DIS
# Add Golden Feature: RM_diff_LSTAT
# Add Golden Feature: LSTAT_ratio_RM
# Add Golden Feature: RM_ratio_LSTAT
# Add Golden Feature: CHAS_diff_LSTAT
# Add Golden Feature: LSTAT_sum_CHAS
# Add Golden Feature: LSTAT_multiply_TAX
# Created 10 Golden Features in 1.03 seconds.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# 6_Default_Xgboost_GoldenFeatures rmse 3.583898 trained in 5.59 seconds
# Skip kmeans_features because of the time limit.
# Not enough time to perform features selection. Skip
# Time needed for features selection ~ 22.0 seconds
# Please increase total_time_limit to at least (277 seconds) to have features selection
# Skip insert_random_feature because no parameters were generated.
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 19 models
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# 62_Xgboost rmse 3.504797 trained in 6.67 seconds
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# 63_Xgboost_GoldenFeatures rmse 3.894451 trained in 8.42 seconds
# 64_LightGBM rmse 3.828625 trained in 21.12 seconds
# Skip hill_climbing_2 because of the time limit.
# * Step ensemble will try to check up to 1 model
# Ensemble rmse 3.403927 trained in 3.56 seconds
# AutoML fit time: 141.25 seconds
# AutoML best model: Ensemble
# CPU times: user 1min 58s, sys: 31.8 s, total: 2min 30s
# Wall time: 2min 21s
# AutoML(mode='Compete', random_state=10, total_time_limit=120)

# %%
# %%time

# Optuna mode
automl_optuna = AutoML(mode="Optuna", total_time_limit=120, optuna_time_budget=120, random_state=RANDOM_STATE)
automl_optuna.fit(x_train, y_train)
# Out:
# AutoML directory: AutoML_4
# Expected computing time:
# Time for tuning with Optuna: len(algorithms) * optuna_time_budget = 720 seconds
# There is no time limit for ML model training after Optuna tuning (total_time_limit parameter is ignored).
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network']
# AutoML will stack models
# AutoML will ensemble availabe models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'ensemble', 'stack', 'ensemble_stacked']
# Skip simple_algorithms because no parameters were generated.
# * Step default_algorithms will try to check up to 6 models
# [I 2021-08-30 09:08:20,376] A new study created in memory with name: no-name-967179ce-d484-47cd-bd39-a09742fc3f30
# Optuna optimizes LightGBM with time budget 120 seconds eval_metric rmse (minimize)
# [I 2021-08-30 09:08:24,161] Trial 0 finished with value: 0.7242525036980104 and parameters: {'learning_rate': 0.0125, 'num_leaves': 1022, 'lambda_l1': 1.0547992438188775e-06, 'lambda_l2': 6.061300044367956e-07, 'feature_fraction': 0.8323715061445782, 'bagging_fraction': 0.41837758728488317, 'bagging_freq': 1, 'min_data_in_leaf': 69, 'extra_trees': True}. Best is trial 0 with value: 0.7242525036980104.
# [I 2021-08-30 09:08:27,584] Trial 1 finished with value: 0.7179059586295856 and parameters: {'learning_rate': 0.025, 'num_leaves': 599, 'lambda_l1': 1.8195630232649103, 'lambda_l2': 0.02698870526662559, 'feature_fraction': 0.6797810630333265, 'bagging_fraction': 0.39951903474276934, 'bagging_freq': 3, 'min_data_in_leaf': 68, 'extra_trees': True}. Best is trial 1 with value: 0.7179059586295856.
# [I 2021-08-30 09:08:35,742] Trial 2 finished with value: 0.35443873327736847 and parameters: {'learning_rate': 0.05, 'num_leaves': 1650, 'lambda_l1': 0.0004952498715186091, 'lambda_l2': 1.5060518616773197, 'feature_fraction': 0.5234652654843426, 'bagging_fraction': 0.3633215453942286, 'bagging_freq': 3, 'min_data_in_leaf': 12, 'extra_trees': True}. Best is trial 2 with value: 0.35443873327736847.
# [I 2021-08-30 09:08:43,805] Trial 3 finished with value: 0.29889324818364865 and parameters: {'learning_rate': 0.05, 'num_leaves': 1755, 'lambda_l1': 1.4617521957829217e-05, 'lambda_l2': 0.061919754212729834, 'feature_fraction': 0.5071731977753922, 'bagging_fraction': 0.9187555445321951, 'bagging_freq': 3, 'min_data_in_leaf': 17, 'extra_trees': True}. Best is trial 3 with value: 0.29889324818364865.
# [I 2021-08-30 09:08:49,171] Trial 4 finished with value: 0.4893200056545929 and parameters: {'learning_rate': 0.1, 'num_leaves': 2023, 'lambda_l1': 0.00012786183233975197, 'lambda_l2': 0.27233633875662455, 'feature_fraction': 0.4759618964586828, 'bagging_fraction': 0.7181601597353354, 'bagging_freq': 7, 'min_data_in_leaf': 54, 'extra_trees': True}. Best is trial 3 with value: 0.29889324818364865.
# [I 2021-08-30 09:09:24,813] Trial 5 finished with value: 0.26868505613692234 and parameters: {'learning_rate': 0.0125, 'num_leaves': 1586, 'lambda_l1': 2.288931933810997e-08, 'lambda_l2': 7.335498048378477e-05, 'feature_fraction': 0.5204488134391505, 'bagging_fraction': 0.7455438065121927, 'bagging_freq': 3, 'min_data_in_leaf': 5, 'extra_trees': True}. Best is trial 5 with value: 0.26868505613692234.
# [I 2021-08-30 09:09:28,781] Trial 6 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:09:29,794] Trial 7 finished with value: 0.6616473070076835 and parameters: {'learning_rate': 0.05, 'num_leaves': 1015, 'lambda_l1': 6.219085582599869, 'lambda_l2': 9.267539038121981e-05, 'feature_fraction': 0.5227909670179939, 'bagging_fraction': 0.6638578953107359, 'bagging_freq': 5, 'min_data_in_leaf': 86, 'extra_trees': False}. Best is trial 5 with value: 0.26868505613692234.
# [I 2021-08-30 09:09:46,011] Trial 8 finished with value: 0.28156371110254874 and parameters: {'learning_rate': 0.0125, 'num_leaves': 719, 'lambda_l1': 0.001171429510270195, 'lambda_l2': 4.983894629660013e-06, 'feature_fraction': 0.6586339124148259, 'bagging_fraction': 0.7714268544339735, 'bagging_freq': 2, 'min_data_in_leaf': 6, 'extra_trees': True}. Best is trial 5 with value: 0.26868505613692234.
# [I 2021-08-30 09:10:01,916] Trial 9 finished with value: 0.33070198099173714 and parameters: {'learning_rate': 0.025, 'num_leaves': 1542, 'lambda_l1': 9.160438419488822e-08, 'lambda_l2': 0.05028392465556407, 'feature_fraction': 0.628849710106199, 'bagging_fraction': 0.718778975877933, 'bagging_freq': 2, 'min_data_in_leaf': 19, 'extra_trees': True}. Best is trial 5 with value: 0.26868505613692234.
# [I 2021-08-30 09:10:03,539] Trial 10 finished with value: 0.30483603341592486 and parameters: {'learning_rate': 0.1, 'num_leaves': 58, 'lambda_l1': 1.201827761330218e-08, 'lambda_l2': 1.6112891744524823e-08, 'feature_fraction': 0.9356144827159025, 'bagging_fraction': 0.9727748934030142, 'bagging_freq': 5, 'min_data_in_leaf': 34, 'extra_trees': False}. Best is trial 5 with value: 0.26868505613692234.
# [I 2021-08-30 09:10:35,951] Trial 11 finished with value: 0.22401275620020644 and parameters: {'learning_rate': 0.0125, 'num_leaves': 486, 'lambda_l1': 0.006925639180901979, 'lambda_l2': 0.0004500555598864005, 'feature_fraction': 0.7499668770201643, 'bagging_fraction': 0.8164900229317867, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'extra_trees': False}. Best is trial 11 with value: 0.22401275620020644.
# 1_Optuna_LightGBM rmse 3.084996 trained in 298.85 seconds
# [I 2021-08-30 09:15:44,103] A new study created in memory with name: no-name-4b72b1cc-7e9c-4643-91f6-352d461dea4f
# Optuna optimizes Xgboost with time budget 120 seconds eval_metric rmse (minimize)
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:15:46,272] Trial 0 finished with value: 0.2631508325920125 and parameters: {'eta': 0.0125, 'max_depth': 7, 'lambda': 1.0547992438188775e-06, 'alpha': 6.061300044367956e-07, 'colsample_bytree': 0.8323715061445782, 'subsample': 0.41837758728488317, 'min_child_weight': 9}. Best is trial 0 with value: 0.2631508325920125.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:15:47,280] Trial 1 finished with value: 0.42958125001027153 and parameters: {'eta': 0.025, 'max_depth': 10, 'lambda': 0.003256376421394008, 'alpha': 0.03131827670437561, 'colsample_bytree': 0.5043132506382039, 'subsample': 0.9424418949368014, 'min_child_weight': 72}. Best is trial 0 with value: 0.2631508325920125.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:15:47,624] Trial 2 finished with value: 0.41660893049534836 and parameters: {'eta': 0.1, 'max_depth': 6, 'lambda': 8.056120247993029e-05, 'alpha': 0.0036299680810414838, 'colsample_bytree': 0.659196774919456, 'subsample': 0.7552780338559988, 'min_child_weight': 61}. Best is trial 0 with value: 0.2631508325920125.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:15:47,923] Trial 3 finished with value: 0.6994209215917412 and parameters: {'eta': 0.05, 'max_depth': 2, 'lambda': 5.085111847677709e-06, 'alpha': 1.0613515458050516e-07, 'colsample_bytree': 0.8800769367021868, 'subsample': 0.332827424041438, 'min_child_weight': 63}. Best is trial 0 with value: 0.2631508325920125.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:15:48,146] Trial 4 finished with value: 0.3120076143166402 and parameters: {'eta': 0.1, 'max_depth': 5, 'lambda': 0.061919754212729834, 'alpha': 4.609516372878068e-06, 'colsample_bytree': 0.9187555445321951, 'subsample': 0.5278581497376905, 'min_child_weight': 17}. Best is trial 0 with value: 0.2631508325920125.
# [I 2021-08-30 09:15:48,734] Trial 5 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:15:49,144] Trial 6 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:15:49,499] Trial 7 finished with value: 0.3192541033727244 and parameters: {'eta': 0.1, 'max_depth': 5, 'lambda': 2.442734160438011e-08, 'alpha': 0.8303029303494638, 'colsample_bytree': 0.8342684186329825, 'subsample': 0.9146676586883671, 'min_child_weight': 42}. Best is trial 0 with value: 0.2631508325920125.
# [I 2021-08-30 09:15:49,974] Trial 8 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:15:50,548] Trial 9 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:15:50,861] Trial 10 finished with value: 0.9663407159870453 and parameters: {'eta': 0.0125, 'max_depth': 10, 'lambda': 1.097145190221902e-06, 'alpha': 3.1881144731578795e-05, 'colsample_bytree': 0.7460963015239255, 'subsample': 0.30419931561698765, 'min_child_weight': 100}. Best is trial 0 with value: 0.2631508325920125.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:15:53,335] Trial 11 finished with value: 0.23334992061626902 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.10744291424225778, 'alpha': 3.1786877425770687e-06, 'colsample_bytree': 0.9812576959826312, 'subsample': 0.4827595907176475, 'min_child_weight': 2}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:15:54,624] Trial 12 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:15:57,600] Trial 13 finished with value: 0.2673586212839218 and parameters: {'eta': 0.0125, 'max_depth': 12, 'lambda': 0.024719259862852415, 'alpha': 0.0004757172991803185, 'colsample_bytree': 0.9975500813521452, 'subsample': 0.4360739653635061, 'min_child_weight': 1}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:15:58,337] Trial 14 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:15:58,990] Trial 15 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:00,964] Trial 16 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:02,033] Trial 17 pruned. Trial was pruned at iteration 536.
# [I 2021-08-30 09:16:02,916] Trial 18 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:03,533] Trial 19 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:04,245] Trial 20 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:07,894] Trial 21 finished with value: 0.26677721465291343 and parameters: {'eta': 0.0125, 'max_depth': 11, 'lambda': 0.02591385736330569, 'alpha': 0.0003159049560366882, 'colsample_bytree': 0.9742431354576285, 'subsample': 0.45650705179731066, 'min_child_weight': 1}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:16:10,044] Trial 22 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:11,405] Trial 23 finished with value: 0.24562745616071505 and parameters: {'eta': 0.0125, 'max_depth': 9, 'lambda': 0.014874633292167688, 'alpha': 0.0001561507189219207, 'colsample_bytree': 0.9732321350847278, 'subsample': 0.6076368606166316, 'min_child_weight': 5}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:16:12,579] Trial 24 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:13,730] Trial 25 finished with value: 0.25613888269303753 and parameters: {'eta': 0.0125, 'max_depth': 9, 'lambda': 0.24781599392184853, 'alpha': 5.281604602569045e-05, 'colsample_bytree': 0.9427102054159419, 'subsample': 0.5752765948957931, 'min_child_weight': 7}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:16:14,675] Trial 26 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:15,276] Trial 27 finished with value: 0.31789037494229294 and parameters: {'eta': 0.05, 'max_depth': 12, 'lambda': 0.004497110853286687, 'alpha': 2.9641412179623226e-05, 'colsample_bytree': 0.7079720287851909, 'subsample': 0.6709427970078022, 'min_child_weight': 31}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:15,970] Trial 28 finished with value: 0.41072495538995035 and parameters: {'eta': 0.025, 'max_depth': 9, 'lambda': 0.1744425015790088, 'alpha': 0.001711259998686149, 'colsample_bytree': 0.8762290432865268, 'subsample': 0.5759679452528856, 'min_child_weight': 40}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:17,761] Trial 29 finished with value: 0.2556025077950655 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 3.096531046185551, 'alpha': 0.017903057116554863, 'colsample_bytree': 0.7934049542127222, 'subsample': 0.6979272383961251, 'min_child_weight': 8}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:16:18,605] Trial 30 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:19,746] Trial 31 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:21,965] Trial 32 finished with value: 0.25998516980323133 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 2.692668258544468, 'alpha': 0.006129279627866907, 'colsample_bytree': 0.9949188597604552, 'subsample': 0.694625798049236, 'min_child_weight': 5}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:16:22,964] Trial 33 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:23,899] Trial 34 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:24,682] Trial 35 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:25,165] Trial 36 finished with value: 0.4946831552697041 and parameters: {'eta': 0.1, 'max_depth': 7, 'lambda': 1.129311460838341, 'alpha': 1.7453271433083526e-05, 'colsample_bytree': 0.9596472673459038, 'subsample': 0.7384844739367572, 'min_child_weight': 75}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:25,940] Trial 37 finished with value: 0.24675612298788624 and parameters: {'eta': 0.05, 'max_depth': 6, 'lambda': 0.04241930566950854, 'alpha': 0.00342815401526994, 'colsample_bytree': 0.790922427383741, 'subsample': 0.49942461008589123, 'min_child_weight': 7}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:26,200] Trial 38 finished with value: 0.6897894253234923 and parameters: {'eta': 0.05, 'max_depth': 6, 'lambda': 0.0009899009170250244, 'alpha': 0.005084988671794685, 'colsample_bytree': 0.5859849231892612, 'subsample': 0.4955833602615214, 'min_child_weight': 82}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:26,746] Trial 39 finished with value: 0.28086298623712475 and parameters: {'eta': 0.05, 'max_depth': 4, 'lambda': 0.056860622214721164, 'alpha': 0.015570812752651967, 'colsample_bytree': 0.6600459402298854, 'subsample': 0.8387900067368973, 'min_child_weight': 1}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:27,703] Trial 40 finished with value: 0.2914677547592758 and parameters: {'eta': 0.05, 'max_depth': 6, 'lambda': 0.05221885023852956, 'alpha': 0.158782779862429, 'colsample_bytree': 0.5362678848100464, 'subsample': 0.7032422721205153, 'min_child_weight': 15}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:28,265] Trial 41 finished with value: 0.26761863952413073 and parameters: {'eta': 0.05, 'max_depth': 8, 'lambda': 0.1569549752058849, 'alpha': 0.0018886322936838592, 'colsample_bytree': 0.8439561926886323, 'subsample': 0.5508560490966663, 'min_child_weight': 7}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:28,789] Trial 42 finished with value: 0.25919522941969 and parameters: {'eta': 0.1, 'max_depth': 7, 'lambda': 0.01136989850424928, 'alpha': 7.142124453015397e-05, 'colsample_bytree': 0.7757840194030253, 'subsample': 0.49275499004459644, 'min_child_weight': 7}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:29,236] Trial 43 finished with value: 0.6038672518893506 and parameters: {'eta': 0.05, 'max_depth': 9, 'lambda': 1.464996511500871, 'alpha': 8.941757029033154e-06, 'colsample_bytree': 0.928531988262578, 'subsample': 0.5381510887086065, 'min_child_weight': 66}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:16:30,000] Trial 44 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:30,655] Trial 45 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:31,715] Trial 46 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:32,128] Trial 47 finished with value: 0.3303918034981215 and parameters: {'eta': 0.1, 'max_depth': 8, 'lambda': 0.3154217463476677, 'alpha': 0.016919035412444442, 'colsample_bytree': 0.4433972027892243, 'subsample': 0.7148966698195421, 'min_child_weight': 26}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:16:32,644] Trial 48 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:33,771] Trial 49 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:34,257] Trial 50 finished with value: 0.30603517512662876 and parameters: {'eta': 0.05, 'max_depth': 9, 'lambda': 0.7907272191250552, 'alpha': 0.002466773481893666, 'colsample_bytree': 0.908223372519894, 'subsample': 0.549592462163726, 'min_child_weight': 17}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:34,669] Trial 51 finished with value: 0.24052186602844045 and parameters: {'eta': 0.1, 'max_depth': 7, 'lambda': 0.01020259262864921, 'alpha': 0.00022348375793689753, 'colsample_bytree': 0.7734381036622222, 'subsample': 0.4743059504563235, 'min_child_weight': 6}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:35,051] Trial 52 finished with value: 0.2586502961615814 and parameters: {'eta': 0.1, 'max_depth': 6, 'lambda': 0.006665773659571505, 'alpha': 0.00016585638527946592, 'colsample_bytree': 0.8134713620724865, 'subsample': 0.35035592315495856, 'min_child_weight': 5}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:35,386] Trial 53 finished with value: 0.25099829539060664 and parameters: {'eta': 0.1, 'max_depth': 5, 'lambda': 0.014723890990885637, 'alpha': 8.461275747170043e-06, 'colsample_bytree': 0.6379069779713826, 'subsample': 0.4578717256353062, 'min_child_weight': 9}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:35,700] Trial 54 finished with value: 0.31058803373050975 and parameters: {'eta': 0.1, 'max_depth': 5, 'lambda': 0.018137515151243868, 'alpha': 0.0007097596378761695, 'colsample_bytree': 0.6181155379538859, 'subsample': 0.3758169478236063, 'min_child_weight': 14}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:36,030] Trial 55 finished with value: 0.27390025160631565 and parameters: {'eta': 0.1, 'max_depth': 5, 'lambda': 0.001686662200725996, 'alpha': 9.328639862429363e-06, 'colsample_bytree': 0.6488508154387709, 'subsample': 0.44400669186222125, 'min_child_weight': 1}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:36,354] Trial 56 finished with value: 0.26547340872943775 and parameters: {'eta': 0.1, 'max_depth': 4, 'lambda': 0.002846113723406609, 'alpha': 0.006246368849783362, 'colsample_bytree': 0.5778218514445891, 'subsample': 0.4175632840821574, 'min_child_weight': 10}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:36,812] Trial 57 finished with value: 0.2570455978836345 and parameters: {'eta': 0.1, 'max_depth': 7, 'lambda': 0.0002639426239266208, 'alpha': 5.423526288524487e-08, 'colsample_bytree': 0.6971064943339873, 'subsample': 0.302412237220697, 'min_child_weight': 4}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:37,140] Trial 58 finished with value: 0.3048420666551054 and parameters: {'eta': 0.1, 'max_depth': 5, 'lambda': 0.013040885334598844, 'alpha': 2.5913738383427274e-06, 'colsample_bytree': 0.753129039582552, 'subsample': 0.4774496635135541, 'min_child_weight': 13}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:37,667] Trial 59 finished with value: 0.6302573556963627 and parameters: {'eta': 0.1, 'max_depth': 6, 'lambda': 4.9309376495989365e-05, 'alpha': 0.00023032753275194884, 'colsample_bytree': 0.6560312138512291, 'subsample': 0.40163827219511045, 'min_child_weight': 56}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:37,927] Trial 60 finished with value: 0.3319390607165132 and parameters: {'eta': 0.1, 'max_depth': 3, 'lambda': 0.0006495577339717129, 'alpha': 6.150326978197779e-07, 'colsample_bytree': 0.7291924606221994, 'subsample': 0.515228090765057, 'min_child_weight': 20}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:39,473] Trial 61 finished with value: 0.24453706149130072 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.08997902737793351, 'alpha': 3.5271288843039996e-05, 'colsample_bytree': 0.9807288154898703, 'subsample': 0.5593523682993113, 'min_child_weight': 4}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:40,726] Trial 62 finished with value: 0.25505962953982886 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.05251860267567276, 'alpha': 6.422081822195599e-06, 'colsample_bytree': 0.9747194952197745, 'subsample': 0.60448216018498, 'min_child_weight': 9}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:42,631] Trial 63 finished with value: 0.24152694123746096 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.04886245894438652, 'alpha': 2.377495479108471e-05, 'colsample_bytree': 0.9803279427585792, 'subsample': 0.6080114123723351, 'min_child_weight': 3}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:44,264] Trial 64 finished with value: 0.23856475025352158 and parameters: {'eta': 0.0125, 'max_depth': 7, 'lambda': 0.03861967156041984, 'alpha': 3.61806508625039e-05, 'colsample_bytree': 0.9668444232615311, 'subsample': 0.4631678871567818, 'min_child_weight': 2}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:47,803] Trial 65 finished with value: 0.2601220259069161 and parameters: {'eta': 0.0125, 'max_depth': 7, 'lambda': 0.10246669192425835, 'alpha': 1.8490231487015694e-05, 'colsample_bytree': 0.9847638830325367, 'subsample': 0.516307391843086, 'min_child_weight': 1}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:49,528] Trial 66 finished with value: 0.24359229452954548 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.003253880800842867, 'alpha': 3.113317344304981e-05, 'colsample_bytree': 0.932042291407503, 'subsample': 0.5562650491355079, 'min_child_weight': 4}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:51,348] Trial 67 finished with value: 0.2445092251933708 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.004051730020337871, 'alpha': 3.4362932315798626e-05, 'colsample_bytree': 0.9255647536305166, 'subsample': 0.6355286260721916, 'min_child_weight': 4}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:53,382] Trial 68 finished with value: 0.2478357393454143 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.002716566183644503, 'alpha': 2.851689742388052e-05, 'colsample_bytree': 0.9267318385565532, 'subsample': 0.5533387884758233, 'min_child_weight': 4}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:16:56,149] Trial 69 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:16:57,202] Trial 70 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:16:58,566] Trial 71 finished with value: 0.2541356586148817 and parameters: {'eta': 0.0125, 'max_depth': 9, 'lambda': 0.003945360987369688, 'alpha': 4.338061060301216e-05, 'colsample_bytree': 0.9998813654396903, 'subsample': 0.5897004698552133, 'min_child_weight': 5}. Best is trial 11 with value: 0.23334992061626902.
# [I 2021-08-30 09:16:59,497] Trial 72 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:00,883] Trial 73 finished with value: 0.24584948548647492 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.018950674409250263, 'alpha': 0.00010619569458120394, 'colsample_bytree': 0.9622731234228868, 'subsample': 0.5355166555073946, 'min_child_weight': 4}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:03,499] Trial 74 finished with value: 0.24909684571443594 and parameters: {'eta': 0.0125, 'max_depth': 7, 'lambda': 0.030453472719607882, 'alpha': 0.0005652898679124007, 'colsample_bytree': 0.9841896621314634, 'subsample': 0.6360397115498173, 'min_child_weight': 11}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:05,005] Trial 75 finished with value: 0.25508679455225325 and parameters: {'eta': 0.0125, 'max_depth': 9, 'lambda': 0.08251766360871361, 'alpha': 2.9525733485768043e-05, 'colsample_bytree': 0.9149326679808323, 'subsample': 0.6726520504237, 'min_child_weight': 6}. Best is trial 11 with value: 0.23334992061626902.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:07,441] Trial 76 finished with value: 0.22919011048984217 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.00789742283515979, 'alpha': 3.266185187119584e-06, 'colsample_bytree': 0.9439467767716354, 'subsample': 0.47732203253202954, 'min_child_weight': 2}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:08,980] Trial 77 finished with value: 0.2562953740592801 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.008480470493963856, 'alpha': 2.9809261974623917e-06, 'colsample_bytree': 0.8631576795947022, 'subsample': 0.44407178975642264, 'min_child_weight': 3}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:10,076] Trial 78 finished with value: 0.24303685853086723 and parameters: {'eta': 0.025, 'max_depth': 7, 'lambda': 0.24055861805357082, 'alpha': 3.984549359605582e-06, 'colsample_bytree': 0.9445669012235695, 'subsample': 0.47920571487496116, 'min_child_weight': 9}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:10,721] Trial 79 finished with value: 0.29702900133893745 and parameters: {'eta': 0.025, 'max_depth': 7, 'lambda': 0.2377045975835776, 'alpha': 4.585700434097039e-06, 'colsample_bytree': 0.9497221930320582, 'subsample': 0.46989057512693566, 'min_child_weight': 15}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:12,350] Trial 80 finished with value: 0.25039578727834166 and parameters: {'eta': 0.025, 'max_depth': 7, 'lambda': 0.36925380354245696, 'alpha': 1.7260600756930292e-06, 'colsample_bytree': 0.8954822516743682, 'subsample': 0.42682674033906104, 'min_child_weight': 9}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:13,926] Trial 81 finished with value: 0.2505945661781753 and parameters: {'eta': 0.025, 'max_depth': 8, 'lambda': 0.06217698653296161, 'alpha': 1.4197408599431408e-05, 'colsample_bytree': 0.9310086620394922, 'subsample': 0.48509488567677855, 'min_child_weight': 3}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:16,186] Trial 82 finished with value: 0.2562441352097611 and parameters: {'eta': 0.025, 'max_depth': 8, 'lambda': 0.03523693190624952, 'alpha': 4.6864781007085764e-07, 'colsample_bytree': 0.9763352344871014, 'subsample': 0.5216964133106011, 'min_child_weight': 1}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:18,254] Trial 83 finished with value: 0.24205937822321935 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.003996074588640772, 'alpha': 7.256951436768274e-05, 'colsample_bytree': 0.9984717706796169, 'subsample': 0.4597814841616506, 'min_child_weight': 8}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:20,038] Trial 84 finished with value: 0.24510243543987476 and parameters: {'eta': 0.0125, 'max_depth': 7, 'lambda': 0.002468703928915386, 'alpha': 4.500070691001158e-06, 'colsample_bytree': 0.9990021420452978, 'subsample': 0.4575438014997713, 'min_child_weight': 8}. Best is trial 76 with value: 0.22919011048984217.
# [I 2021-08-30 09:17:21,081] Trial 85 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:22,794] Trial 86 finished with value: 0.24842127299382846 and parameters: {'eta': 0.0125, 'max_depth': 6, 'lambda': 0.003761170127521381, 'alpha': 0.00027877418464441187, 'colsample_bytree': 0.8782848091487934, 'subsample': 0.4270502031368781, 'min_child_weight': 7}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:24,138] Trial 87 finished with value: 0.279280444861712 and parameters: {'eta': 0.025, 'max_depth': 8, 'lambda': 0.005187995722776724, 'alpha': 1.9241554350041505e-05, 'colsample_bytree': 0.9132160064186247, 'subsample': 0.37429982887568014, 'min_child_weight': 10}. Best is trial 76 with value: 0.22919011048984217.
# [I 2021-08-30 09:17:24,990] Trial 88 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:17:26,312] Trial 89 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:28,527] Trial 90 finished with value: 0.25384257525468085 and parameters: {'eta': 0.0125, 'max_depth': 8, 'lambda': 0.009844224082805454, 'alpha': 6.535870609846731e-05, 'colsample_bytree': 0.96487985077206, 'subsample': 0.5340085908452781, 'min_child_weight': 6}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:33,173] Trial 91 finished with value: 0.2423086426188531 and parameters: {'eta': 0.0125, 'max_depth': 9, 'lambda': 0.19176577935426894, 'alpha': 3.7581857632147515e-05, 'colsample_bytree': 0.980687959611808, 'subsample': 0.5868701613976754, 'min_child_weight': 3}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:36,847] Trial 92 finished with value: 0.2544040712215745 and parameters: {'eta': 0.0125, 'max_depth': 9, 'lambda': 0.02233976844878627, 'alpha': 1.331809726667616e-05, 'colsample_bytree': 0.9391538412858264, 'subsample': 0.5929617496749843, 'min_child_weight': 2}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:38,929] Trial 93 finished with value: 0.24351249772410327 and parameters: {'eta': 0.0125, 'max_depth': 9, 'lambda': 0.191941320555167, 'alpha': 4.1370931154895545e-05, 'colsample_bytree': 0.8985126973952415, 'subsample': 0.4683154139664474, 'min_child_weight': 8}. Best is trial 76 with value: 0.22919011048984217.
# [I 2021-08-30 09:17:39,916] Trial 94 pruned. Trial was pruned at iteration 500.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:41,880] Trial 95 finished with value: 0.24925536144821012 and parameters: {'eta': 0.0125, 'max_depth': 9, 'lambda': 0.1563455861376081, 'alpha': 0.0004093259624673305, 'colsample_bytree': 0.9904494242356062, 'subsample': 0.48811418830473785, 'min_child_weight': 9}. Best is trial 76 with value: 0.22919011048984217.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [I 2021-08-30 09:17:43,361] Trial 96 finished with value: 0.24829853954076214 and parameters: {'eta': 0.0125, 'max_depth': 9, 'lambda': 5.879318619489876e-08, 'alpha': 0.0002146406532637385, 'colsample_bytree': 0.9686288688348983, 'subsample': 0.5058157881896299, 'min_child_weight': 7}. Best is trial 76 with value: 0.22919011048984217.
# [I 2021-08-30 09:17:43,973] Trial 97 pruned. Trial was pruned at iteration 500.
# [I 2021-08-30 09:17:44,917] Trial 98 pruned. Trial was pruned at iteration 500.
# Data has no positive values, and therefore can not be log-scaled.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# 2_Optuna_Xgboost rmse 3.086692 trained in 37.73 seconds
# [I 2021-08-30 09:18:35,206] A new study created in memory with name: no-name-51142e7f-b618-4f93-818f-35fb1e8fa9f5
# Optuna optimizes CatBoost with time budget 120 seconds eval_metric rmse (minimize)
# [I 2021-08-30 09:18:35,978] Trial 0 finished with value: 0.3660115423417631 and parameters: {'learning_rate': 0.05, 'depth': 7, 'l2_leaf_reg': 4.985120272324674, 'random_strength': 2.24796646306051, 'rsm': 0.27825657828366157, 'min_data_in_leaf': 77}. Best is trial 0 with value: 0.3660115423417631.
# [I 2021-08-30 09:18:39,113] Trial 1 finished with value: 0.5575558947866532 and parameters: {'learning_rate': 0.2, 'depth': 9, 'l2_leaf_reg': 0.039582268452511726, 'random_strength': 5.121922638735843, 'rsm': 0.8313588654869022, 'min_data_in_leaf': 62}. Best is trial 0 with value: 0.3660115423417631.
# [I 2021-08-30 09:18:39,579] Trial 2 finished with value: 0.3406155154351798 and parameters: {'learning_rate': 0.2, 'depth': 7, 'l2_leaf_reg': 5.425489425675812, 'random_strength': 1.421700484593569, 'rsm': 0.43600668404632226, 'min_data_in_leaf': 68}. Best is trial 2 with value: 0.3406155154351798.
# [I 2021-08-30 09:18:39,948] Trial 3 finished with value: 0.317236531824963 and parameters: {'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 6.504006779596479, 'random_strength': 6.010389538035054, 'rsm': 0.8247008771494718, 'min_data_in_leaf': 53}. Best is trial 3 with value: 0.317236531824963.
# [I 2021-08-30 09:18:40,220] Trial 4 finished with value: 0.30151555939627606 and parameters: {'learning_rate': 0.05, 'depth': 4, 'l2_leaf_reg': 1.1399322201993114, 'random_strength': 8.286813264789954, 'rsm': 0.1422066874503248, 'min_data_in_leaf': 63}. Best is trial 4 with value: 0.30151555939627606.
# [I 2021-08-30 09:18:42,814] Trial 5 finished with value: 0.44687932535450736 and parameters: {'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 3.516591229056936, 'random_strength': 7.546476917752095, 'rsm': 0.36636553619171086, 'min_data_in_leaf': 89}. Best is trial 4 with value: 0.30151555939627606.
# [I 2021-08-30 09:18:42,902] Trial 6 finished with value: 0.3158942796613924 and parameters: {'learning_rate': 0.2, 'depth': 2, 'l2_leaf_reg': 8.2110744678035, 'random_strength': 1.5115202049141183, 'rsm': 0.44570300382297967, 'min_data_in_leaf': 95}. Best is trial 4 with value: 0.30151555939627606.
# [I 2021-08-30 09:18:43,392] Trial 7 finished with value: 0.31136923194507476 and parameters: {'learning_rate': 0.05, 'depth': 4, 'l2_leaf_reg': 5.97375674514402, 'random_strength': 9.028317604287956, 'rsm': 0.5811021539216336, 'min_data_in_leaf': 60}. Best is trial 4 with value: 0.30151555939627606.
# [I 2021-08-30 09:18:43,672] Trial 8 finished with value: 0.2661252716886245 and parameters: {'learning_rate': 0.1, 'depth': 4, 'l2_leaf_reg': 3.307260047890122, 'random_strength': 7.738302964367655, 'rsm': 0.13596328782097955, 'min_data_in_leaf': 43}. Best is trial 8 with value: 0.2661252716886245.
# [I 2021-08-30 09:18:43,988] Trial 9 finished with value: 0.27872562492519076 and parameters: {'learning_rate': 0.1, 'depth': 2, 'l2_leaf_reg': 8.799163753661709, 'random_strength': 7.632405873804403, 'rsm': 0.8902869784523725, 'min_data_in_leaf': 42}. Best is trial 8 with value: 0.2661252716886245.
# [I 2021-08-30 09:18:44,151] Trial 10 finished with value: 0.2917753462910819 and parameters: {'learning_rate': 0.1, 'depth': 4, 'l2_leaf_reg': 2.5632261315098694, 'random_strength': 3.4453207614671726, 'rsm': 0.11312185732259922, 'min_data_in_leaf': 13}. Best is trial 8 with value: 0.2661252716886245.
# [I 2021-08-30 09:18:44,889] Trial 11 finished with value: 0.2635292352190589 and parameters: {'learning_rate': 0.1, 'depth': 2, 'l2_leaf_reg': 9.79008665170551, 'random_strength': 6.591839954194943, 'rsm': 0.6659539329301176, 'min_data_in_leaf': 29}. Best is trial 11 with value: 0.2635292352190589.
# [I 2021-08-30 09:18:45,929] Trial 12 finished with value: 0.2633791027664998 and parameters: {'learning_rate': 0.1, 'depth': 3, 'l2_leaf_reg': 9.672011965872164, 'random_strength': 6.236509830119381, 'rsm': 0.6651866086333454, 'min_data_in_leaf': 28}. Best is trial 12 with value: 0.2633791027664998.
# [I 2021-08-30 09:18:46,466] Trial 13 finished with value: 0.2709295292004439 and parameters: {'learning_rate': 0.1, 'depth': 2, 'l2_leaf_reg': 9.918001538908683, 'random_strength': 5.87951062417582, 'rsm': 0.6562547235107099, 'min_data_in_leaf': 21}. Best is trial 12 with value: 0.2633791027664998.
# [I 2021-08-30 09:18:47,013] Trial 14 finished with value: 0.28581131923026803 and parameters: {'learning_rate': 0.1, 'depth': 3, 'l2_leaf_reg': 7.73578620305585, 'random_strength': 3.7541151443848113, 'rsm': 0.6965884997142813, 'min_data_in_leaf': 27}. Best is trial 12 with value: 0.2633791027664998.
# [I 2021-08-30 09:18:47,475] Trial 15 finished with value: 0.2708616122304818 and parameters: {'learning_rate': 0.1, 'depth': 3, 'l2_leaf_reg': 9.805577798224315, 'random_strength': 9.884357257884822, 'rsm': 0.9996573031739096, 'min_data_in_leaf': 4}. Best is trial 12 with value: 0.2633791027664998.
# [I 2021-08-30 09:18:48,133] Trial 16 finished with value: 0.3649672920385437 and parameters: {'learning_rate': 0.1, 'depth': 5, 'l2_leaf_reg': 7.167242762906092, 'random_strength': 6.369892750041278, 'rsm': 0.716134726379942, 'min_data_in_leaf': 32}. Best is trial 12 with value: 0.2633791027664998.
# [I 2021-08-30 09:18:48,468] Trial 17 finished with value: 0.3019779667164434 and parameters: {'learning_rate': 0.1, 'depth': 3, 'l2_leaf_reg': 8.859946401813144, 'random_strength': 4.336516311632864, 'rsm': 0.5515245018785321, 'min_data_in_leaf': 35}. Best is trial 12 with value: 0.2633791027664998.
# [I 2021-08-30 09:18:49,212] Trial 18 finished with value: 0.25187629169927045 and parameters: {'learning_rate': 0.1, 'depth': 5, 'l2_leaf_reg': 9.044905415136927, 'random_strength': 0.12451212750149221, 'rsm': 0.74854513616775, 'min_data_in_leaf': 17}. Best is trial 18 with value: 0.25187629169927045.
# [I 2021-08-30 09:18:49,866] Trial 19 finished with value: 0.2550289326540753 and parameters: {'learning_rate': 0.05, 'depth': 5, 'l2_leaf_reg': 7.112374810088143, 'random_strength': 0.04606161159362898, 'rsm': 0.7758511848551508, 'min_data_in_leaf': 2}. Best is trial 18 with value: 0.25187629169927045.
# [I 2021-08-30 09:18:51,216] Trial 20 finished with value: 0.2646131131992116 and parameters: {'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 6.9661274684587, 'random_strength': 0.019919896994134947, 'rsm': 0.9864584628987769, 'min_data_in_leaf': 2}. Best is trial 18 with value: 0.25187629169927045.
# [I 2021-08-30 09:18:51,985] Trial 21 finished with value: 0.24951337309442803 and parameters: {'learning_rate': 0.05, 'depth': 5, 'l2_leaf_reg': 8.686162822459698, 'random_strength': 0.3942938577370058, 'rsm': 0.7803379090526877, 'min_data_in_leaf': 14}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:18:52,784] Trial 22 finished with value: 0.2555534035506036 and parameters: {'learning_rate': 0.05, 'depth': 5, 'l2_leaf_reg': 8.324905481879899, 'random_strength': 0.16475362385032813, 'rsm': 0.80815775175105, 'min_data_in_leaf': 13}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:18:53,772] Trial 23 finished with value: 0.297116812965612 and parameters: {'learning_rate': 0.05, 'depth': 5, 'l2_leaf_reg': 7.694234435642557, 'random_strength': 0.8641847846648002, 'rsm': 0.7797005926196418, 'min_data_in_leaf': 14}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:18:55,771] Trial 24 finished with value: 0.3350195190523681 and parameters: {'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 9.00448188421357, 'random_strength': 2.5425146753558376, 'rsm': 0.9030089182423424, 'min_data_in_leaf': 7}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:18:58,557] Trial 25 finished with value: 0.3187690915533528 and parameters: {'learning_rate': 0.05, 'depth': 7, 'l2_leaf_reg': 4.732684023140827, 'random_strength': 0.9997676152405202, 'rsm': 0.7509246271224106, 'min_data_in_leaf': 20}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:18:59,724] Trial 26 finished with value: 0.31109395869248296 and parameters: {'learning_rate': 0.05, 'depth': 5, 'l2_leaf_reg': 6.705708444903059, 'random_strength': 2.4597785024035237, 'rsm': 0.9068195772665011, 'min_data_in_leaf': 20}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:19:00,763] Trial 27 finished with value: 0.29183311482885227 and parameters: {'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 7.538380529962405, 'random_strength': 0.610799717848596, 'rsm': 0.6117158087470342, 'min_data_in_leaf': 1}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:19:01,739] Trial 28 finished with value: 0.2822455971814642 and parameters: {'learning_rate': 0.05, 'depth': 5, 'l2_leaf_reg': 6.125999034486233, 'random_strength': 1.5366049981188679, 'rsm': 0.49566802142427957, 'min_data_in_leaf': 10}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:19:03,031] Trial 29 finished with value: 0.36270849646859354 and parameters: {'learning_rate': 0.05, 'depth': 7, 'l2_leaf_reg': 4.771961986605508, 'random_strength': 3.13456954716756, 'rsm': 0.7460728403099337, 'min_data_in_leaf': 38}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:19:06,901] Trial 30 finished with value: 0.3750493579751682 and parameters: {'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 8.335049184613991, 'random_strength': 2.123667862831629, 'rsm': 0.8567518378117764, 'min_data_in_leaf': 20}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:19:07,799] Trial 31 finished with value: 0.25267590935157463 and parameters: {'learning_rate': 0.05, 'depth': 5, 'l2_leaf_reg': 8.271965431331743, 'random_strength': 0.02647154369732011, 'rsm': 0.7902607694444214, 'min_data_in_leaf': 11}. Best is trial 21 with value: 0.24951337309442803.
# [I 2021-08-30 09:19:08,304] Trial 32 finished with value: 0.24875664872624426 and parameters: {'learning_rate': 0.05, 'depth': 4, 'l2_leaf_reg': 8.737487904557689, 'random_strength': 0.051594806060976495, 'rsm': 0.7753312065730334, 'min_data_in_leaf': 9}. Best is trial 32 with value: 0.24875664872624426.
# [I 2021-08-30 09:19:08,522] Trial 33 finished with value: 0.2805021265057237 and parameters: {'learning_rate': 0.2, 'depth': 4, 'l2_leaf_reg': 9.225777235522749, 'random_strength': 0.70123523471408, 'rsm': 0.6230513134035558, 'min_data_in_leaf': 16}. Best is trial 32 with value: 0.24875664872624426.
# [I 2021-08-30 09:19:10,190] Trial 34 finished with value: 0.32300181316824417 and parameters: {'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 8.229085879931072, 'random_strength': 2.0737569995489356, 'rsm': 0.9370779513249952, 'min_data_in_leaf': 24}. Best is trial 32 with value: 0.24875664872624426.
# [I 2021-08-30 09:19:10,592] Trial 35 finished with value: 0.2681259269037469 and parameters: {'learning_rate': 0.2, 'depth': 4, 'l2_leaf_reg': 9.315778281499567, 'random_strength': 1.2749711409293492, 'rsm': 0.8512863715472243, 'min_data_in_leaf': 8}. Best is trial 32 with value: 0.24875664872624426.
# [I 2021-08-30 09:19:11,338] Trial 36 finished with value: 0.2577032853291432 and parameters: {'learning_rate': 0.05, 'depth': 5, 'l2_leaf_reg': 5.5072954012140904, 'random_strength': 0.5223645296211628, 'rsm': 0.820051633476243, 'min_data_in_leaf': 8}. Best is trial 32 with value: 0.24875664872624426.
# [I 2021-08-30 09:19:12,554] Trial 37 finished with value: 0.35156839195301415 and parameters: {'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 8.680697319110843, 'random_strength': 1.5826028055729773, 'rsm': 0.710376098761199, 'min_data_in_leaf': 76}. Best is trial 32 with value: 0.24875664872624426.
# [I 2021-08-30 09:19:12,871] Trial 38 finished with value: 0.2761961116958773 and parameters: {'learning_rate': 0.2, 'depth': 4, 'l2_leaf_reg': 0.7196254137650797, 'random_strength': 1.8436514280495715, 'rsm': 0.9534868535911137, 'min_data_in_leaf': 50}. Best is trial 32 with value: 0.24875664872624426.
# ...
# [I 2021-08-30 09:23:38,706] Trial 252 finished with value: 0.2637200448905384 and parameters: {'dense_1_size': 61, 'dense_2_size': 58, 'learning_rate': 0.005, 'learning_rate_type': 'constant', 'alpha': 8.052683742505614e-08}. Best is trial 139 with value: 0.24695992351636945.
# [I 2021-08-30 09:23:39,041] Trial 253 finished with value: 0.31971803363135326 and parameters: {'dense_1_size': 57, 'dense_2_size': 58, 'learning_rate': 0.05, 'learning_rate_type': 'constant', 'alpha': 5.991658007822817e-08}. Best is trial 139 with value: 0.24695992351636945.
# [I 2021-08-30 09:23:40,151] Trial 254 finished with value: 0.2636009698891657 and parameters: {'dense_1_size': 63, 'dense_2_size': 62, 'learning_rate': 0.005, 'learning_rate_type': 'adaptive', 'alpha': 3.642131590667575e-08}. Best is trial 139 with value: 0.24695992351636945.
# [I 2021-08-30 09:23:40,523] Trial 255 finished with value: 0.31613241404985043 and parameters: {'dense_1_size': 61, 'dense_2_size': 61, 'learning_rate': 0.005, 'learning_rate_type': 'adaptive', 'alpha': 4.531261802103944e-08}. Best is trial 139 with value: 0.24695992351636945.
# [I 2021-08-30 09:23:42,417] Trial 256 finished with value: 0.28123503225370344 and parameters: {'dense_1_size': 63, 'dense_2_size': 64, 'learning_rate': 0.005, 'learning_rate_type': 'constant', 'alpha': 6.789550536057689e-08}. Best is trial 139 with value: 0.24695992351636945.
# 4_Optuna_NeuralNetwork rmse 3.508449 trained in 16.24 seconds
# [I 2021-08-30 09:25:24,454] A new study created in memory with name: no-name-62ffe1fa-fd6b-4105-a641-6c8af3518e5b
# Optuna optimizes Random Forest with time budget 120 seconds eval_metric rmse (minimize)
# [I 2021-08-30 09:25:30,177] Trial 0 finished with value: 0.6455784814504855 and parameters: {'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 64, 'max_features': 0.7513158437132257}. Best is trial 0 with value: 0.6455784814504855.
# [I 2021-08-30 09:25:36,346] Trial 1 finished with value: 0.42361667272727305 and parameters: {'max_depth': 17, 'min_samples_split': 24, 'min_samples_leaf': 20, 'max_features': 0.7629254050769692}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:25:41,843] Trial 2 finished with value: 0.6638389000793256 and parameters: {'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 69, 'max_features': 0.9538594127329871}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:25:47,364] Trial 3 finished with value: 0.7376711240249851 and parameters: {'max_depth': 2, 'min_samples_split': 52, 'min_samples_leaf': 82, 'max_features': 0.6164008061610943}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:25:52,801] Trial 4 finished with value: 0.7347968610501222 and parameters: {'max_depth': 24, 'min_samples_split': 30, 'min_samples_leaf': 92, 'max_features': 0.7174300255637137}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:25:58,509] Trial 5 finished with value: 0.5421414999979217 and parameters: {'max_depth': 18, 'min_samples_split': 16, 'min_samples_leaf': 38, 'max_features': 0.6773922789156819}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:26:04,274] Trial 6 finished with value: 0.6542808057581728 and parameters: {'max_depth': 15, 'min_samples_split': 44, 'min_samples_leaf': 62, 'max_features': 0.518006860128847}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:26:09,670] Trial 7 finished with value: 0.7452304958272612 and parameters: {'max_depth': 22, 'min_samples_split': 61, 'min_samples_leaf': 81, 'max_features': 0.5264306808696978}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:26:15,533] Trial 8 finished with value: 0.43361908276445316 and parameters: {'max_depth': 30, 'min_samples_split': 33, 'min_samples_leaf': 10, 'max_features': 0.3076930560698413}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:26:21,101] Trial 9 finished with value: 0.4938076519113306 and parameters: {'max_depth': 5, 'min_samples_split': 84, 'min_samples_leaf': 5, 'max_features': 0.6300242768282787}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:26:26,556] Trial 10 finished with value: 0.7274226011037594 and parameters: {'max_depth': 12, 'min_samples_split': 98, 'min_samples_leaf': 34, 'max_features': 0.09996008085277264}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:26:33,328] Trial 11 finished with value: 0.43078824571294383 and parameters: {'max_depth': 30, 'min_samples_split': 32, 'min_samples_leaf': 3, 'max_features': 0.2641220947827905}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:26:38,933] Trial 12 finished with value: 0.506188337902162 and parameters: {'max_depth': 32, 'min_samples_split': 25, 'min_samples_leaf': 24, 'max_features': 0.32201329491787906}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:26:44,757] Trial 13 finished with value: 0.5489198547524491 and parameters: {'max_depth': 19, 'min_samples_split': 65, 'min_samples_leaf': 17, 'max_features': 0.3021535096967535}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:26:50,461] Trial 14 finished with value: 0.5818184460482423 and parameters: {'max_depth': 11, 'min_samples_split': 34, 'min_samples_leaf': 43, 'max_features': 0.9420588836499917}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:26:56,055] Trial 15 finished with value: 0.5339363302636326 and parameters: {'max_depth': 27, 'min_samples_split': 17, 'min_samples_leaf': 3, 'max_features': 0.014440457278434127}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:27:01,795] Trial 16 finished with value: 0.5860586850170901 and parameters: {'max_depth': 21, 'min_samples_split': 45, 'min_samples_leaf': 25, 'max_features': 0.20877164015314348}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:27:07,658] Trial 17 finished with value: 0.48309099714624076 and parameters: {'max_depth': 13, 'min_samples_split': 71, 'min_samples_leaf': 21, 'max_features': 0.8506217943700863}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:27:13,179] Trial 18 finished with value: 0.6281385710486109 and parameters: {'max_depth': 16, 'min_samples_split': 22, 'min_samples_leaf': 51, 'max_features': 0.44394906890525276}. Best is trial 1 with value: 0.42361667272727305.
# [I 2021-08-30 09:27:18,947] Trial 19 finished with value: 0.4025663805843492 and parameters: {'max_depth': 28, 'min_samples_split': 2, 'min_samples_leaf': 13, 'max_features': 0.42409351770377424}. Best is trial 19 with value: 0.4025663805843492.
# [I 2021-08-30 09:27:24,496] Trial 20 finished with value: 0.51745991497885 and parameters: {'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 30, 'max_features': 0.4180964416690817}. Best is trial 19 with value: 0.4025663805843492.
# 5_Optuna_RandomForest rmse 4.03431 trained in 27.83 seconds
# [I 2021-08-30 09:27:59,829] A new study created in memory with name: no-name-0a59f938-6e80-437e-94b8-98f14f52780c
# Optuna optimizes Extra Trees with time budget 120 seconds eval_metric rmse (minimize)
# [I 2021-08-30 09:28:03,836] Trial 0 finished with value: 0.7371936665833879 and parameters: {'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 64, 'max_features': 0.7513158437132257}. Best is trial 0 with value: 0.7371936665833879.
# [I 2021-08-30 09:28:07,826] Trial 1 finished with value: 0.5189326445993763 and parameters: {'max_depth': 17, 'min_samples_split': 24, 'min_samples_leaf': 20, 'max_features': 0.7629254050769692}. Best is trial 1 with value: 0.5189326445993763.
# [I 2021-08-30 09:28:12,016] Trial 2 finished with value: 0.7209703847768242 and parameters: {'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 69, 'max_features': 0.9538594127329871}. Best is trial 1 with value: 0.5189326445993763.
# [I 2021-08-30 09:28:15,847] Trial 3 finished with value: 0.7760595927642704 and parameters: {'max_depth': 2, 'min_samples_split': 52, 'min_samples_leaf': 82, 'max_features': 0.6164008061610943}. Best is trial 1 with value: 0.5189326445993763.
# [I 2021-08-30 09:28:19,692] Trial 4 finished with value: 0.790645671144142 and parameters: {'max_depth': 24, 'min_samples_split': 30, 'min_samples_leaf': 92, 'max_features': 0.7174300255637137}. Best is trial 1 with value: 0.5189326445993763.
# [I 2021-08-30 09:28:23,604] Trial 5 finished with value: 0.6546320993290978 and parameters: {'max_depth': 18, 'min_samples_split': 16, 'min_samples_leaf': 38, 'max_features': 0.6773922789156819}. Best is trial 1 with value: 0.5189326445993763.
# [I 2021-08-30 09:28:27,555] Trial 6 finished with value: 0.7641773155161797 and parameters: {'max_depth': 15, 'min_samples_split': 44, 'min_samples_leaf': 62, 'max_features': 0.518006860128847}. Best is trial 1 with value: 0.5189326445993763.
# [I 2021-08-30 09:28:31,332] Trial 7 finished with value: 0.7960395832110613 and parameters: {'max_depth': 22, 'min_samples_split': 61, 'min_samples_leaf': 81, 'max_features': 0.5264306808696978}. Best is trial 1 with value: 0.5189326445993763.
# [I 2021-08-30 09:28:35,490] Trial 8 finished with value: 0.5525192495842781 and parameters: {'max_depth': 30, 'min_samples_split': 33, 'min_samples_leaf': 10, 'max_features': 0.3076930560698413}. Best is trial 1 with value: 0.5189326445993763.
# [I 2021-08-30 09:28:39,514] Trial 9 finished with value: 0.4747385450171498 and parameters: {'max_depth': 5, 'min_samples_split': 84, 'min_samples_leaf': 5, 'max_features': 0.6300242768282787}. Best is trial 9 with value: 0.4747385450171498.
# [I 2021-08-30 09:28:43,351] Trial 10 finished with value: 0.6983692263638759 and parameters: {'max_depth': 10, 'min_samples_split': 93, 'min_samples_leaf': 1, 'max_features': 0.06129737401724922}. Best is trial 9 with value: 0.4747385450171498.
# [I 2021-08-30 09:28:49,093] Trial 11 finished with value: 0.5728893847368047 and parameters: {'max_depth': 12, 'min_samples_split': 83, 'min_samples_leaf': 27, 'max_features': 0.8237991384513877}. Best is trial 9 with value: 0.4747385450171498.
# [I 2021-08-30 09:28:53,120] Trial 12 finished with value: 0.7005024894829973 and parameters: {'max_depth': 3, 'min_samples_split': 79, 'min_samples_leaf': 24, 'max_features': 0.3278203386844624}. Best is trial 9 with value: 0.4747385450171498.
# [I 2021-08-30 09:28:57,472] Trial 13 finished with value: 0.47863973622207373 and parameters: {'max_depth': 19, 'min_samples_split': 65, 'min_samples_leaf': 16, 'max_features': 0.9283079239200431}. Best is trial 9 with value: 0.4747385450171498.
# [I 2021-08-30 09:29:01,556] Trial 14 finished with value: 0.6267436814563129 and parameters: {'max_depth': 32, 'min_samples_split': 69, 'min_samples_leaf': 43, 'max_features': 0.943739546511112}. Best is trial 9 with value: 0.4747385450171498.
# [I 2021-08-30 09:29:05,510] Trial 15 finished with value: 0.5643301438887572 and parameters: {'max_depth': 20, 'min_samples_split': 95, 'min_samples_leaf': 2, 'max_features': 0.3497287573026968}. Best is trial 9 with value: 0.4747385450171498.
# [I 2021-08-30 09:29:09,777] Trial 16 finished with value: 0.49137071585664666 and parameters: {'max_depth': 7, 'min_samples_split': 71, 'min_samples_leaf': 15, 'max_features': 0.9024096152064801}. Best is trial 9 with value: 0.4747385450171498.
# [I 2021-08-30 09:29:13,516] Trial 17 finished with value: 0.884552863379868 and parameters: {'max_depth': 13, 'min_samples_split': 56, 'min_samples_leaf': 35, 'max_features': 0.04553436157816154}. Best is trial 9 with value: 0.4747385450171498.
# [I 2021-08-30 09:29:17,338] Trial 18 finished with value: 0.8481376067724417 and parameters: {'max_depth': 9, 'min_samples_split': 84, 'min_samples_leaf': 53, 'max_features': 0.18733961161047946}. Best is trial 9 with value: 0.4747385450171498.
# [I 2021-08-30 09:29:21,577] Trial 19 finished with value: 0.4382253865256858 and parameters: {'max_depth': 26, 'min_samples_split': 65, 'min_samples_leaf': 10, 'max_features': 0.9991723840304525}. Best is trial 19 with value: 0.4382253865256858.
# [I 2021-08-30 09:29:25,727] Trial 20 finished with value: 0.6437187237214548 and parameters: {'max_depth': 26, 'min_samples_split': 100, 'min_samples_leaf': 30, 'max_features': 0.6136184783104341}. Best is trial 19 with value: 0.4382253865256858.
# [I 2021-08-30 09:29:29,865] Trial 21 finished with value: 0.4434043127985626 and parameters: {'max_depth': 28, 'min_samples_split': 69, 'min_samples_leaf': 10, 'max_features': 0.9956449210478263}. Best is trial 19 with value: 0.4382253865256858.
# [I 2021-08-30 09:29:33,982] Trial 22 finished with value: 0.4009302607569473 and parameters: {'max_depth': 28, 'min_samples_split': 43, 'min_samples_leaf': 8, 'max_features': 0.8511688485675506}. Best is trial 22 with value: 0.4009302607569473.
# [I 2021-08-30 09:29:38,384] Trial 23 finished with value: 0.4081924451893381 and parameters: {'max_depth': 28, 'min_samples_split': 42, 'min_samples_leaf': 11, 'max_features': 0.995695600065066}. Best is trial 22 with value: 0.4009302607569473.
# [I 2021-08-30 09:29:42,394] Trial 24 finished with value: 0.43512729320011545 and parameters: {'max_depth': 28, 'min_samples_split': 41, 'min_samples_leaf': 13, 'max_features': 0.8584064449099166}. Best is trial 22 with value: 0.4009302607569473.
# [I 2021-08-30 09:29:47,593] Trial 25 finished with value: 0.6496757440565247 and parameters: {'max_depth': 29, 'min_samples_split': 41, 'min_samples_leaf': 46, 'max_features': 0.8600325928941295}. Best is trial 22 with value: 0.4009302607569473.
# [I 2021-08-30 09:29:51,574] Trial 26 finished with value: 0.5050915317969351 and parameters: {'max_depth': 32, 'min_samples_split': 44, 'min_samples_leaf': 20, 'max_features': 0.8209837659631439}. Best is trial 22 with value: 0.4009302607569473.
# [I 2021-08-30 09:29:55,692] Trial 27 finished with value: 0.5809218965832179 and parameters: {'max_depth': 22, 'min_samples_split': 36, 'min_samples_leaf': 33, 'max_features': 0.8578805931909625}. Best is trial 22 with value: 0.4009302607569473.
# [I 2021-08-30 09:29:59,892] Trial 28 finished with value: 0.6435023140482036 and parameters: {'max_depth': 28, 'min_samples_split': 21, 'min_samples_leaf': 24, 'max_features': 0.4379569701365515}. Best is trial 22 with value: 0.4009302607569473.
# 6_Optuna_ExtraTrees rmse 3.950397 trained in 25.83 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble rmse 2.91224 trained in 0.94 seconds
# * Step stack will try to check up to 6 models
# 3_Optuna_CatBoost_Stacked rmse 3.293028 trained in 11.82 seconds
# 1_Optuna_LightGBM_Stacked rmse 3.118665 trained in 289.53 seconds
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# 2_Optuna_Xgboost_Stacked rmse 3.18738 trained in 43.94 seconds
# 4_Optuna_NeuralNetwork_Stacked rmse 4.02128 trained in 21.64 seconds
# 6_Optuna_ExtraTrees_Stacked rmse 2.967898 trained in 18.03 seconds
# 5_Optuna_RandomForest_Stacked rmse 3.033101 trained in 17.6 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked rmse 2.887482 trained in 1.78 seconds
# AutoML fit time: 1769.12 seconds
# AutoML best model: Ensemble_Stacked
# CPU times: user 25min 23s, sys: 6min 13s, total: 31min 36s
# Wall time: 29min 29s
# AutoML(mode='Optuna', optuna_time_budget=120, random_state=10,
#        total_time_limit=120)

# %%
# 評価
def calculate_scores(true, pred):
    """全ての評価指標を計算する

    Parameters
    ----------
    true (np.array)       : 実測値
    pred (np.array)       : 予測値

    Returns
    -------
    scores (pd.DataFrame) : 各評価指標を纏めた結果

    """
    scores = {}
    scores = pd.DataFrame(
        {
            "R2": r2_score(true, pred),
            "MAE": mean_absolute_error(true, pred),
            "MSE": mean_squared_error(true, pred),
            "RMSE": np.sqrt(mean_squared_error(true, pred)),
        },
        index=["scores"],
    )
    return scores

# %%
# 推論
y_pred_explain = automl_explain.predict(x_test)
y_pred_perform = automl_perform.predict(x_test)
y_pred_compete = automl_compete.predict(x_test)
y_pred_optuna = automl_optuna.predict(x_test)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
scores_explain = calculate_scores(y_test, y_pred_explain)
scores_perform = calculate_scores(y_test, y_pred_perform)
scores_compete = calculate_scores(y_test, y_pred_compete)
scores_optuna = calculate_scores(y_test, y_pred_optuna)
print(scores_explain)
print(scores_perform)
print(scores_compete)
print(scores_optuna)
# Out:
#               R2      MAE        MSE      RMSE
# scores  0.790832  3.15528  21.874963  4.677068
#               R2       MAE        MSE     RMSE
# scores  0.828431  2.749082  17.942766  4.23589
#              R2       MAE        MSE      RMSE
# scores  0.85749  2.791346  14.903854  3.860551
#               R2       MAE        MSE      RMSE
# scores  0.884163  2.340199  12.114279  3.480557

# %%
automl_explain.get_leaderboard()
# Out:
#                       name      model_type metric_type  metric_value  \
# 0               1_Baseline        Baseline        rmse      9.863249
# 1           2_DecisionTree   Decision Tree        rmse      5.632212
# 2                 3_Linear          Linear        rmse      5.562562
# 3        4_Default_Xgboost         Xgboost        rmse      4.158365
# 4  5_Default_NeuralNetwork  Neural Network        rmse      5.806764
# 5   6_Default_RandomForest   Random Forest        rmse      4.889840
# 6                 Ensemble        Ensemble        rmse      4.158365
#
#    train_time
# 0        1.56
# 1       28.45
# 2        9.56
# 3       15.86
# 4        3.32
# 5       13.66
# 6        0.90

# %%
automl_perform.get_leaderboard()
# Out:
#                  name model_type metric_type  metric_value  train_time  \
# 0            1_Linear     Linear        rmse      4.613829        9.90
# 1  2_Default_LightGBM   LightGBM        rmse      3.262666       45.53
# 2          7_LightGBM   LightGBM        rmse      3.399441       34.62
# 3          8_LightGBM   LightGBM        rmse      3.262666       47.73
# 4            Ensemble   Ensemble        rmse      3.200319        0.63
#
#    single_prediction_time
# 0                  0.1703
# 1                  0.0927
# 2                  0.1010
# 3                  0.1073
# 4                  0.2844

# %%
automl_compete.get_leaderboard()
# Out:
#                                 name         model_type metric_type  \
# 0                     1_DecisionTree      Decision Tree        rmse
# 1                     2_DecisionTree      Decision Tree        rmse
# 2                     3_DecisionTree      Decision Tree        rmse
# 3                           4_Linear             Linear        rmse
# 4                 5_Default_LightGBM           LightGBM        rmse
# 5                  6_Default_Xgboost            Xgboost        rmse
# 6                        16_LightGBM           LightGBM        rmse
# 7                          7_Xgboost            Xgboost        rmse
# 8                        25_CatBoost           CatBoost        rmse
# 9                    34_RandomForest      Random Forest        rmse
# 10                     43_ExtraTrees        Extra Trees        rmse
# 11                  52_NeuralNetwork     Neural Network        rmse
# 12               61_NearestNeighbors  Nearest Neighbors        rmse
# 13  6_Default_Xgboost_GoldenFeatures            Xgboost        rmse
# 14                        62_Xgboost            Xgboost        rmse
# 15         63_Xgboost_GoldenFeatures            Xgboost        rmse
# 16                       64_LightGBM           LightGBM        rmse
# 17                          Ensemble           Ensemble        rmse
#
#     metric_value  train_time
# 0       4.162736        1.90
# 1       6.857707        1.88
# 2       4.681484        2.00
# 3       6.106102        2.23
# 4       3.828625       17.93
# 5       3.537102        4.19
# 6       3.986159       12.25
# 7       4.215637        2.79
# 8       5.013433        4.02
# 9       4.787280        4.17
# 10      4.116552        3.13
# 11      7.168914        2.03
# 12      5.402386        3.15
# 13      3.583898        7.52
# 14      3.504797        7.78
# 15      3.894451        9.53
# 16      3.828625       22.12
# 17      3.403927        3.56

# %%
automl_optuna.get_leaderboard()
# Out:
#                               name      model_type metric_type  metric_value  \
# 0                1_Optuna_LightGBM        LightGBM        rmse      3.084996
# 1                 2_Optuna_Xgboost         Xgboost        rmse      3.086692
# 2                3_Optuna_CatBoost        CatBoost        rmse      2.961985
# 3           4_Optuna_NeuralNetwork  Neural Network        rmse      3.508449
# 4            5_Optuna_RandomForest   Random Forest        rmse      4.034310
# 5              6_Optuna_ExtraTrees     Extra Trees        rmse      3.950397
# 6                         Ensemble        Ensemble        rmse      2.912240
# 7        3_Optuna_CatBoost_Stacked        CatBoost        rmse      3.293028
# 8        1_Optuna_LightGBM_Stacked        LightGBM        rmse      3.118665
# 9         2_Optuna_Xgboost_Stacked         Xgboost        rmse      3.187380
# 10  4_Optuna_NeuralNetwork_Stacked  Neural Network        rmse      4.021280
# 11     6_Optuna_ExtraTrees_Stacked     Extra Trees        rmse      2.967898
# 12   5_Optuna_RandomForest_Stacked   Random Forest        rmse      3.033101
# 13                Ensemble_Stacked        Ensemble        rmse      2.887482
#
#     train_time
# 0       301.15
# 1        39.86
# 2        13.64
# 3        18.11
# 4        30.16
# 5        28.17
# 6         0.94
# 7        13.98
# 8       292.27
# 9        46.06
# 10       23.20
# 11       22.97
# 12       18.90
# 13        1.78
